# %% [markdown]
# # PYTHON PROGRAMMING FUNDAMENTALS

# %% [markdown]
# 다음 토픽을 다룹니다. :
# - Functions
# - Lambda Expressions
# - Map

# %% [markdown]
# # FUNCTIONS
# - 함수란, 재사용 되는 코드 블럭 입니다.
# - Data or arguments 가 전달되고, 결과가 return 됩니다.
# - 우리가 프로그래밍 하다가, 반복되거나 재사용 되는 코드 블럭이 있으면, 이를 함수로 만들면 됩니다.
# - 남들이 이렇게 재사용 잘 되는 함수들을 미리 만들어 놓은 것들도 많습니다. 이를 라이브러리라고 합니다.

# %% [markdown]
# ## 함수를 나타내는 정의 (문법) 를 외우자.
# - ### def
# - ### 함수이름
# - ### 파라미터의 의미
# - ### 리턴이란?

# %% [markdown]
# ![python-function.svg](attachment:python-function.svg)

# %% [markdown]
# ## 함수의 실행 순서를 이해하자.
# - ### CPU가 어떠한 실행 순서로 동작하는가?

# %% [markdown]
# ![how_does_python_function_work.jpg](attachment:how_does_python_function_work.jpg)

# %% [markdown]
# ## return 이 없는 경우

# %% [markdown]
# ## Parameter가 하나인 경우

# %%
# 어떤 숫자 1개를 입력으로 주면, 그 숫자를 제곱해서 리턴하는 함수

# %% [markdown]
# ## Parameters 가 두개인 경우

# %%
# 어떤 숫자와, 제곱 횟수를 입력받으면, 그 숫자의 몇제곱해서 리턴
# 하는 함수

# %% [markdown]
# ## Return 값이 둘 이상인 경우

# %%
# 숫자 두개를 입력받으면, 그 숫자들로 나눠서, 몫과 나머지를 리턴
# 하는 함수

# %% [markdown]
# ## Default parameter

# %%
# 나이를 입력받으면, 나이가 몇인지 화면에 출력하는 함수

# %%
# 이름과 나이를 입력받으면, "제 이름은 ... 이고 나이는 .. 살입니다."
# 를 출력하는 함수.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LAMBDA EXPRESSIONS
# - Lambda function 은 anonymous function 이다. 즉 함ㅅ 이름이 없다.
# - Lambda functions 은 주로 filter(), map() , reduce() 함수와 함께 사용된다. 나중에~
# - 파라미터는 많아도 상관없지만, 연산은 딱 한줄이어야 한다.

# %% [markdown]
# # 함수에 주석을 달 수 있다.

# %% [markdown]
# ## 함수가 어떻게 동작하는지 comment를 달아보자. 이를 docstring 라고 한다.
