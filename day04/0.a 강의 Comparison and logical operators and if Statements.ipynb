# %% [markdown]
# # PYTHON PROGRAMMING FUNDAMENTALS

# %% [markdown]
# # COMPARISON OPERATORS (비교연산자)
# ![image.png](attachment:image.png)
#
# Reference: https://www.tutorialspoint.com/python/python_basic_operators.htm

# %% [markdown]
# ![%E1%84%87%E1%85%B5%E1%84%80%E1%85%AD%E1%84%8B%E1%85%A7%E1%86%AB%E1%84%89%E1%85%A1%E1%86%AB%E1%84%8C%E1%85%A1.png](attachment:%E1%84%87%E1%85%B5%E1%84%80%E1%85%AD%E1%84%8B%E1%85%A7%E1%86%AB%E1%84%89%E1%85%A1%E1%86%AB%E1%84%8C%E1%85%A1.png)

# %% [markdown]
# ![%E1%84%89%E1%85%AE%E1%86%AB%E1%84%89%E1%85%A5.jpg](attachment:%E1%84%89%E1%85%AE%E1%86%AB%E1%84%89%E1%85%A5.jpg)

# %% [markdown]
# # LOGICAL OPERATORS

# %% [markdown]
# ![and.jpeg](attachment:and.jpeg)

# %% [markdown]
# ## 실제 and 연산을 위 4개 조건으로 실행 해봅니다.

# %% [markdown]
# ![or.jpg](attachment:or.jpg)

# %% [markdown]
# ## 실제 or 연산을 위 4개 조건으로 실행 해봅니다.

# %% [markdown]
# ## 여러개의 조합

# %% [markdown]
# # CONDITIONAL STATEMENTS

# %% [markdown]
# ## 조건문이란, 우리 일상생활에서 흔히 쓰는 문장.  if ~ 라면, ~ 한다.

# %% [markdown]
# ### 비가 오면 우산을 들고 나가고, 비가 오지 않으면 놓고간다.
#
# ### 5가 2보다 크면 condition is True 를 출력하고, 그렇지 않으면, condition is False를 출력한다.

# %% [markdown]
# ## 위의 문장에서, 무엇을 주의깊게 봐야 할까요?
#
# ### 파이썬 문법입니다.  '정의' 이므로 이렇게 따라해야만 컴퓨터가 이해할 수 있습니다.
#
# ### <font color='blue'> 탭 ! tab !  입니다. 들여쓰기(indentation)가 중요합니다.

# %% [markdown]
# ### 여러 문장을 수행하는 예제

# %% [markdown]
# ## CPU의 코드 실행 순서

# %% [markdown]
# ![python_if.png](attachment:python_if.png)

# %% [markdown]
# ### 위의 식을 작성해봅시다.

# %% [markdown]
# ## Nested 중첩된 조건문
